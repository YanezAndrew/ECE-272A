# %%
import openai
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Get API key from environment variable
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
def call_llm(prompt):
    response = openai.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "user", "content": "You are a python coding assistant. "},
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content

# %%
# Read prompt from the text file
with open('hw1_q1_prompt.txt', 'r') as file:
    prompt = file.read()

# %%
generated_code = call_llm(prompt)
print(generated_code)
# Out:
# import pandas as pd
#
# df = pd.read_csv('./autograder/source/drybean.csv')
# answer_1 = df.head()
# answer_2 = df.columns.tolist()
# answer_3 = df.shape
# answer_4 = df.nunique()

# %%
import pandas as pd

df = pd.read_csv('./autograder/source/drybean.csv')
answer1 = df.head()
answer2 = df.columns.tolist()
answer3 = df.shape
answer4 = df.nunique()
