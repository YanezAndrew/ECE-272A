# %%
import openai
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Get API key from environment variable
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
def call_llm(prompt):
    response = openai.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "user", "content": "You are a python coding assistant. "},
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content

# %%
prompt = """
YOUR PROMPT HERE
"""

# %%
generated_code = call_llm(prompt)
print(generated_code)
# Out:
# Sure! How can I assist you with Python coding today? Whether you need help with writing code, debugging, or understanding concepts, feel free to ask!
